# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from PIL import Image

# %%
from tensorflow.keras.preprocessing import image

# %%
k_img = image.load_img(r"C:\Users\bishw\Downloads\Compressed\dataset\single_prediction\cat_or_dog_1.jpg")

# %%
image.img_to_array(k_img)
# Out:
# array([[[ 57.,  60.,   7.],
#         [ 57.,  60.,   7.],
#         [ 57.,  60.,   7.],
#         ...,
#         [138., 148.,  77.],
#         [138., 148.,  77.],
#         [138., 148.,  77.]],
#
#        [[ 57.,  60.,   7.],
#         [ 57.,  60.,   7.],
#         [ 56.,  59.,   6.],
#         ...,
#         [138., 148.,  77.],
#         [138., 148.,  77.],
#         [138., 148.,  77.]],
#
#        [[ 54.,  58.,   7.],
#         [ 54.,  58.,   7.],
#         [ 54.,  58.,   7.],
#         ...,
#         [138., 148.,  77.],
#         [138., 148.,  77.],
#         [138., 148.,  77.]],
#
#        ...,
#
#        [[ 59.,  62.,  15.],
#         [ 59.,  62.,  15.],
#         [ 58.,  61.,  14.],
#         ...,
#         [230., 200., 172.],
#         [230., 200., 174.],
#         [230., 200., 174.]],
#
#        [[ 59.,  62.,  15.],
#         [ 59.,  62.,  15.],
#         [ 59.,  62.,  15.],
#         ...,
#         [230., 200., 174.],
#         [228., 201., 174.],
# ...

# %%
img = Image.open(r"C:\Users\bishw\Downloads\Compressed\dataset\single_prediction\cat_or_dog_1.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x720 at 0x28653CEAE50>

# %%
img_arr = np.asarray(img)
img_arr
# Out:
# array([[[ 57,  60,   7],
#         [ 57,  60,   7],
#         [ 57,  60,   7],
#         ...,
#         [138, 148,  77],
#         [138, 148,  77],
#         [138, 148,  77]],
#
#        [[ 57,  60,   7],
#         [ 57,  60,   7],
#         [ 56,  59,   6],
#         ...,
#         [138, 148,  77],
#         [138, 148,  77],
#         [138, 148,  77]],
#
#        [[ 54,  58,   7],
#         [ 54,  58,   7],
#         [ 54,  58,   7],
#         ...,
#         [138, 148,  77],
#         [138, 148,  77],
#         [138, 148,  77]],
#
#        ...,
#
#        [[ 59,  62,  15],
#         [ 59,  62,  15],
#         [ 58,  61,  14],
#         ...,
#         [230, 200, 172],
#         [230, 200, 174],
#         [230, 200, 174]],
#
#        [[ 59,  62,  15],
#         [ 59,  62,  15],
#         [ 59,  62,  15],
#         ...,
#         [230, 200, 174],
#         [228, 201, 174],
#         [228, 200, 176]],
#
#        [[ 59,  62,  15],
#         [ 59,  62,  15],
#         [ 59,  62,  15],
# ...

# %%
img_arr.shape
# Out:
# (720, 960, 3)

# %%
img_red = img_arr[:,:,0]
img_green = img_arr[:,:,1]
img_blue = img_arr[:,:,2]

# %%
plt.imshow(img_red)

# %%
plt.imshow(img_green)

# %%
plt.imshow(img_blue)

# %%
img_arr_copy = img_arr.copy()

# %% [markdown]
# # No Red

# %%
img_arr_copy[:,:,0] = 0

# %%
plt.imshow(img_arr_copy)

# %% [markdown]
# # No Green

# %%
img_arr_copy = img_arr.copy()

# %%
img_arr_copy[:,:,1] = 0

# %%
plt.imshow(img_arr_copy)

# %% [markdown]
# # No Blue

# %%
img_arr_copy = img_arr.copy()

# %%
img_arr_copy[:,:,2] = 0

# %%
plt.imshow(img_arr_copy)

# %% [markdown]
# # Only Red

# %%
img_arr_copy = img_arr.copy()

img_arr_copy[:,:,1:] = 0

plt.imshow(img_arr_copy)

# %% [markdown]
# # Only Green

# %%
img_arr_copy = img_arr.copy()

img_arr_copy[:,:,0] = 0
img_arr_copy[:,:,2] = 0


plt.imshow(img_arr_copy)

# %% [markdown]
# # Only Blue

# %%
img_arr_copy = img_arr.copy()

img_arr_copy[:,:,1] = 0
img_arr_copy[:,:,0] = 0


plt.imshow(img_arr_copy)

# %% [markdown]
# 1. Three channels when stacked on top of another will be viwed as a coloured image
# 2. All channel have values ranges from 0, 255
# 3. For each channel 0 means no colour for that channel and 255 means the greatest intensity of colour for that channel
